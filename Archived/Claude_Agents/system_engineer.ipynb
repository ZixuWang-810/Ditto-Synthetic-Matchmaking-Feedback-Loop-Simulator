# %%
# import anthropic
import os
# from dotenv import load_dotenv #  loads environment variables from a .env file 
from agent import Agent

# load_dotenv()
# from dotenv import load_dotenv
# import os
# import anthropic

# load_dotenv()  # must come first

# client = anthropic.Anthropic(api_key=os.getenv("ANTHROPIC_API_KEY"))
# print(os.getenv("ANTHROPIC_API_KEY"))
# Out:
# sk-ant-placeholder

# %%
role = 'You are a professional system engineer'
system_prompt = 'Design project with high level consideration and follow the industry rules'
system_ag = Agent(role = role, system_prompt = system_prompt)

# %%
system_ag.chat('Who are you')
# Out:
# '# Who I Am\n\nI am **Claude**, an AI assistant made by **Anthropic**.\n\n## What I Can Help You With:\n\n- 💡 **Design Projects** – Architecture, engineering, product design\n- 📐 **Industry Standards & Codes** – Building codes, regulations, best practices\n- 🏗️ **High-Level Planning** – Conceptual design, feasibility studies\n- 📊 **Technical Analysis** – Calculations, specifications, recommendations\n- ✍️ **Documentation** – Reports, proposals, technical writing\n\n---\n\n## How I Approach Design Projects:\n\n✅ Follow **industry rules and standards**\n\n✅ Consider **safety, functionality, and sustainability**\n\n✅ Apply **professional best practices**\n\n✅ Provide **structured, logical solutions**\n\n---\n\n**How can I assist you with your design project today?**'
